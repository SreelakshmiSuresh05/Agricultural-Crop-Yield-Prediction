# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/crop_yield.csv (1).zip')

# %%
df
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 999995   West      Silt     Rice   302.805345            27.987428
# 999996  South    Chalky   Barley   932.991383            39.661039
# 999997  North     Peaty   Cotton   867.362046            24.370042
# 999998   West      Silt    Wheat   492.812857            33.045505
# 999999   West     Sandy    Maize   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                 False             True            Cloudy              122
# ...

# %%
df.head()
# Out:
#   Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0   West     Sandy   Cotton   897.077239            27.676966
# 1  South      Clay     Rice   992.673282            18.026142
# 2  North      Loam   Barley   147.998025            29.794042
# 3  North     Sandy  Soybean   986.866331            16.644190
# 4  South      Silt    Wheat   730.379174            31.620687
#
#    Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0            False             True            Cloudy              122
# 1             True             True             Rainy              140
# 2            False            False             Sunny              106
# 3            False             True             Rainy              146
# 4             True             True            Cloudy              110
#
#    Yield_tons_per_hectare
# 0                6.555816
# 1                8.527341
# 2                1.127443
# 3                6.517573
# 4                7.248251

# %%
df.tail()
# Out:
#        Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  \
# 999995   West      Silt    Rice   302.805345            27.987428
# 999996  South    Chalky  Barley   932.991383            39.661039
# 999997  North     Peaty  Cotton   867.362046            24.370042
# 999998   West      Silt   Wheat   492.812857            33.045505
# 999999   West     Sandy   Maize   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 999995            False            False             Sunny               76
# 999996             True            False             Rainy               93
# 999997             True            False            Cloudy              108
# 999998            False            False             Sunny              102
# 999999             True            False             Sunny               76
#
#         Yield_tons_per_hectare
# 999995                1.347586
# 999996                7.311594
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius',
#        'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition',
#        'Days_to_Harvest', 'Yield_tons_per_hectare'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Region                  1000000 non-null  object
#  1   Soil_Type               1000000 non-null  object
#  2   Crop                    1000000 non-null  object
#  3   Rainfall_mm             1000000 non-null  float64
#  4   Temperature_Celsius     1000000 non-null  float64
#  5   Fertilizer_Used         1000000 non-null  bool
#  6   Irrigation_Used         1000000 non-null  bool
#  7   Weather_Condition       1000000 non-null  object
#  8   Days_to_Harvest         1000000 non-null  int64
#  9   Yield_tons_per_hectare  1000000 non-null  float64
# dtypes: bool(2), float64(3), int64(1), object(4)
# memory usage: 62.9+ MB

# %%
df.describe()
# Out:
#           Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# count  1000000.000000       1000000.000000   1000000.000000
# mean       549.981901            27.504965       104.495025
# std        259.851320             7.220608        25.953412
# min        100.000896            15.000034        60.000000
# 25%        324.891090            21.254502        82.000000
# 50%        550.124061            27.507365       104.000000
# 75%        774.738520            33.753267       127.000000
# max        999.998098            39.999997       149.000000
#
#        Yield_tons_per_hectare
# count          1000000.000000
# mean                 4.649472
# std                  1.696572
# min                 -1.147613
# 25%                  3.417637
# 50%                  4.651808
# 75%                  5.879200
# max                  9.963372

# %%
df.dtypes
# Out:
# Region                     object
# Soil_Type                  object
# Crop                       object
# Rainfall_mm               float64
# Temperature_Celsius       float64
# Fertilizer_Used              bool
# Irrigation_Used              bool
# Weather_Condition          object
# Days_to_Harvest             int64
# Yield_tons_per_hectare    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %% [markdown]
# Filling the missing values:

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Region'].value_counts()
# Out:
# Region
# North    250173
# West     250074
# South    250054
# East     249699
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Region'],data=df,color='springgreen')
plt.title('Region Count Distribution')
plt.show()

# %%
df['Crop'].value_counts()
# Out:
# Crop
# Maize      166824
# Rice       166792
# Barley     166777
# Wheat      166673
# Cotton     166585
# Soybean    166349
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Crop'],data=df,color='lavender')
plt.title('Crop Count Distribution')
plt.show()

# %%
df['Soil_Type'].value_counts()
# Out:
# Soil_Type
# Sandy     167119
# Loam      166795
# Chalky    166779
# Silt      166672
# Clay      166352
# Peaty     166283
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Soil_Type'],data=df,color='slateblue')
plt.title('Soil Type Count Distribution ')
plt.show()

# %%
df['Fertilizer_Used'].value_counts()
# Out:
# Fertilizer_Used
# False    500060
# True     499940
# Name: count, dtype: int64

# %%
y=np.array(['False','True'])
x=np.array(['500060','499940'])
colors=['#99ff99','#00FF00']
plt.pie(x,labels=y,autopct='%1.01f%%',colors=colors)
plt.legend(title='Fertilizer Used',loc='upper right')
plt.title('Crops-Fertilization Usage')
plt.show()

# %%
df['Irrigation_Used'].value_counts()
# Out:
# Irrigation_Used
# False    500509
# True     499491
# Name: count, dtype: int64

# %%
y=np.array(['False','True'])
x=np.array(['500509','499491'])
colors=['#ff9999','#66b3ff']
plt.pie(x,labels=y,autopct='%1.01f%%',colors=colors)
plt.legend(title='Irrigation Used',loc='upper right')
plt.title('Crops-Irrigation Usage')
plt.show()

# %%
df['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Sunny     333790
# Rainy     333561
# Cloudy    332649
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Weather_Condition'],data=df,color='palevioletred')
plt.title('Weather Distribution')
plt.show()

# %%
k=df['Days_to_Harvest'].value_counts()
k
# Out:
# Days_to_Harvest
# 91     11417
# 122    11326
# 72     11295
# 102    11259
# 114    11251
#        ...
# 134    10954
# 139    10951
# 131    10940
# 67     10921
# 149    10864
# Name: count, Length: 90, dtype: int64

# %%
x=k.index
y=k.values
plt.plot(y,x,marker='o')
plt.grid(linestyle='dotted',linewidth=2,color='grey')
plt.xlabel('Days of Harvest',size=8)
plt.ylabel('Count',size=8)
plt.title('Harvest Duration & its Frequency',fontsize=16)
plt.show()

# %%
df.hist(bins=60, figsize =(20,10),color='turquoise')
plt.show()

# %%
correlation_matrix=df.corr(numeric_only='True')
correlation_matrix
# Out:
#                         Rainfall_mm  Temperature_Celsius  Fertilizer_Used  \
# Rainfall_mm                1.000000            -0.000123        -0.001076
# Temperature_Celsius       -0.000123             1.000000         0.002343
# Fertilizer_Used           -0.001076             0.002343         1.000000
# Irrigation_Used           -0.000568            -0.000484         0.001510
# Days_to_Harvest           -0.002669            -0.000731        -0.001029
# Yield_tons_per_hectare     0.764618             0.085565         0.442099
#
#                         Irrigation_Used  Days_to_Harvest  \
# Rainfall_mm                   -0.000568        -0.002669
# Temperature_Celsius           -0.000484        -0.000731
# Fertilizer_Used                0.001510        -0.001029
# Irrigation_Used                1.000000        -0.001234
# Days_to_Harvest               -0.001234         1.000000
# Yield_tons_per_hectare         0.353741        -0.002591
#
# ...

# %% [markdown]
# Exploratory data Analysis(EDA):-
# This step includes
#
# 1..Correlation Analysis using heatmaps to visualize correlations between numerical features and identify important relationships
#
# 2.Visualizing relationships using jointplots,pairplots helps to explore relationship between key variables

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Matrix Heatmap', fontsize=16)
plt.show()

# %%
sns.jointplot(x='Rainfall_mm',y='Yield_tons_per_hectare',data=df,kind='reg',color='firebrick')
plt.suptitle('Impact of Rainfall on Crop Yields',fontsize=12,y=1.02)
plt.show()

# %%
sns.jointplot(x='Temperature_Celsius',y='Yield_tons_per_hectare',data=df,kind='hex',color='green')
plt.suptitle('Impact of Temperature (in Celcius) on Crop Yields',fontsize=12,y=1.02)
plt.show()

# %%
sns.pairplot(data=df,corner=True,palette='pastel',hue='Region')
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(data=df,corner=True,palette='colorblind',hue='Crop')
plt.show()

# %% [markdown]
# Outlier Detection and Removal:Use box plots ,interquartile range(IQR) to detect outliers

# %%
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
numeric_cols=['Rainfall_mm','Temperature_Celsius','Days_to_Harvest','Yield_tons_per_hectare']
for i in numeric_cols:
  plt.figure(figsize=(4,2))
  sns.boxplot(data=df,y=i)
  plt.show()

# %%
numeric_cols=['Rainfall_mm','Temperature_Celsius','Days_to_Harvest','Yield_tons_per_hectare']
for col in numeric_cols:
  Q1= df[col].quantile(0.25)
  Q3= df[col].quantile(0.75)
  IQR=Q3-Q1
  lower_bound=Q1-1.5*IQR
  upper_bound = Q3+1.5*IQR
  df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]
print(df)
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 134710   West      Silt    Maize   958.958693            23.279494
# 134711   West    Chalky     Rice   454.392182            31.510763
# 134712  North      Loam    Maize   963.022054            19.815051
# 134713   West    Chalky  Soybean   728.653892            33.450442
# 134714  North     Peaty    Maize   493.224122            16.524363
#
#        Fertilizer_Used Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                False            True            Cloudy            122.0
# ...

# %% [markdown]
# To convert object type and boolean data into a format suitable for machine learning models,we're using an encoding method called GetDummies. This process transforms each category into a new binary column..

# %%
df1=pd.get_dummies(df[['Region','Soil_Type','Crop','Irrigation_Used','Fertilizer_Used','Weather_Condition']],drop_first='True',dtype=int)
df1
# Out:
#         Region_North  Region_South  Region_West  Soil_Type_Clay  \
# 0                  0             0            1               0
# 1                  0             1            0               1
# 2                  1             0            0               0
# 3                  1             0            0               0
# 4                  0             1            0               0
# ...              ...           ...          ...             ...
# 134710             0             0            1               0
# 134711             0             0            1               0
# 134712             1             0            0               0
# 134713             0             0            1               0
# 134714             1             0            0               0
#
#         Soil_Type_Loam  Soil_Type_Peaty  Soil_Type_Sandy  Soil_Type_Silt  \
# 0                    0                0                1               0
# ...

# %%
new_df=pd.concat([df,df1],axis=1)
new_df
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 134710   West      Silt    Maize   958.958693            23.279494
# 134711   West    Chalky     Rice   454.392182            31.510763
# 134712  North      Loam    Maize   963.022054            19.815051
# 134713   West    Chalky  Soybean   728.653892            33.450442
# 134714  North     Peaty    Maize   493.224122            16.524363
#
#        Fertilizer_Used Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                False            True            Cloudy            122.0
# ...

# %%
new_df.drop(['Region','Soil_Type','Crop','Irrigation_Used','Fertilizer_Used','Weather_Condition'],axis=1,inplace=True)

# %%
new_df
# Out:
#         Rainfall_mm  Temperature_Celsius  Days_to_Harvest  \
# 0        897.077239            27.676966            122.0
# 1        992.673282            18.026142            140.0
# 2        147.998025            29.794042            106.0
# 3        986.866331            16.644190            146.0
# 4        730.379174            31.620687            110.0
# ...             ...                  ...              ...
# 134710   958.958693            23.279494            113.0
# 134711   454.392182            31.510763             64.0
# 134712   963.022054            19.815051            106.0
# 134713   728.653892            33.450442            144.0
# 134714   493.224122            16.524363             65.0
#
#         Yield_tons_per_hectare  Region_North  Region_South  Region_West  \
# 0                     6.555816             0             0            1
# 1                     8.527341             0             1            0
# ...

# %%
new_df.shape
# Out:
# (134703, 21)

# %%
new_df.columns
# Out:
# Index(['Rainfall_mm', 'Temperature_Celsius', 'Days_to_Harvest',
#        'Yield_tons_per_hectare', 'Region_North', 'Region_South', 'Region_West',
#        'Soil_Type_Clay', 'Soil_Type_Loam', 'Soil_Type_Peaty',
#        'Soil_Type_Sandy', 'Soil_Type_Silt', 'Crop_Cotton', 'Crop_Maize',
#        'Crop_Rice', 'Crop_Soybean', 'Crop_Wheat', 'Irrigation_Used_True',
#        'Fertilizer_Used_True', 'Weather_Condition_Rainy',
#        'Weather_Condition_Sunny'],
#       dtype='object')

# %%
new_df.dtypes
# Out:
# Rainfall_mm                float64
# Temperature_Celsius        float64
# Days_to_Harvest            float64
# Yield_tons_per_hectare     float64
# Region_North                 int64
# Region_South                 int64
# Region_West                  int64
# Soil_Type_Clay               int64
# Soil_Type_Loam               int64
# Soil_Type_Peaty              int64
# Soil_Type_Sandy              int64
# Soil_Type_Silt               int64
# Crop_Cotton                  int64
# Crop_Maize                   int64
# Crop_Rice                    int64
# Crop_Soybean                 int64
# Crop_Wheat                   int64
# Irrigation_Used_True         int64
# Fertilizer_Used_True         int64
# Weather_Condition_Rainy      int64
# Weather_Condition_Sunny      int64
# dtype: object

# %%
new_df.isna().sum()
# Out:
# Rainfall_mm                0
# Temperature_Celsius        0
# Days_to_Harvest            0
# Yield_tons_per_hectare     0
# Region_North               0
# Region_South               0
# Region_West                0
# Soil_Type_Clay             0
# Soil_Type_Loam             0
# Soil_Type_Peaty            0
# Soil_Type_Sandy            0
# Soil_Type_Silt             0
# Crop_Cotton                0
# Crop_Maize                 0
# Crop_Rice                  0
# Crop_Soybean               0
# Crop_Wheat                 0
# Irrigation_Used_True       0
# Fertilizer_Used_True       0
# Weather_Condition_Rainy    0
# Weather_Condition_Sunny    0
# dtype: int64

# %%
x=new_df.drop(columns=['Yield_tons_per_hectare'])
x
# Out:
#         Rainfall_mm  Temperature_Celsius  Days_to_Harvest  Region_North  \
# 0        897.077239            27.676966            122.0             0
# 1        992.673282            18.026142            140.0             0
# 2        147.998025            29.794042            106.0             1
# 3        986.866331            16.644190            146.0             1
# 4        730.379174            31.620687            110.0             0
# ...             ...                  ...              ...           ...
# 134710   958.958693            23.279494            113.0             0
# 134711   454.392182            31.510763             64.0             0
# 134712   963.022054            19.815051            106.0             1
# 134713   728.653892            33.450442            144.0             0
# 134714   493.224122            16.524363             65.0             1
#
#         Region_South  Region_West  Soil_Type_Clay  Soil_Type_Loam  \
# ...

# %%
y=new_df['Yield_tons_per_hectare']
y
# Out:
# 0         6.555816
# 1         8.527341
# 2         1.127443
# 3         6.517573
# 4         7.248251
#             ...
# 134710    6.128759
# 134711    4.338023
# 134712    8.313870
# 134713    6.268842
# 134714    3.541265
# Name: Yield_tons_per_hectare, Length: 134703, dtype: float64

# %% [markdown]
# Splitting the data into training and testing sets(70% train,30% test)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#         Rainfall_mm  Temperature_Celsius  Days_to_Harvest  Region_North  \
# 111470   285.886195            38.077842            141.0             1
# 41760    768.625222            17.320667            147.0             0
# 40072    137.269287            30.634417             72.0             0
# 125842   908.293072            28.955605            138.0             0
# 128283   822.637399            30.118002            126.0             1
# ...             ...                  ...              ...           ...
# 110275   719.413933            20.840714             98.0             1
# 119888   968.944487            33.211030            144.0             0
# 103700   380.163923            24.600257             77.0             0
# 131943   846.371390            24.795435             68.0             1
# 121968   989.547448            21.238359            147.0             1
#
#         Region_South  Region_West  Soil_Type_Clay  Soil_Type_Loam  \
# ...

# %%
x_test
# Out:
#         Rainfall_mm  Temperature_Celsius  Days_to_Harvest  Region_North  \
# 28675    370.488525            24.479204             74.0             1
# 59178    275.323762            35.056350             65.0             0
# 89402    908.955196            33.092662            114.0             0
# 110743   410.684762            21.061598            106.0             0
# 10942    303.920290            32.584055            149.0             0
# ...             ...                  ...              ...           ...
# 34531    355.298980            38.829641            149.0             1
# 34148    726.188865            16.772027             75.0             0
# 16345    811.207115            25.675243             82.0             1
# 45647    655.658053            19.495531             92.0             0
# 64102    541.024199            30.351294            140.0             0
#
#         Region_South  Region_West  Soil_Type_Clay  Soil_Type_Loam  \
# ...

# %%
y_train
# Out:
# 111470    2.845069
# 41760     5.983989
# 40072     2.380696
# 125842    6.784472
# 128283    5.027495
#             ...
# 110275    4.277617
# 119888    8.021655
# 103700    1.226135
# 131943    5.399247
# 121968    7.563176
# Name: Yield_tons_per_hectare, Length: 94292, dtype: float64

# %%
y_test
# Out:
# 28675     4.088624
# 59178     3.999311
# 89402     6.939405
# 110743    3.512720
# 10942     3.058866
#             ...
# 34531     4.730183
# 34148     5.762175
# 16345     6.463471
# 45647     5.712621
# 64102     3.238784
# Name: Yield_tons_per_hectare, Length: 40411, dtype: float64

# %% [markdown]
# Standardizing Features for Linear Regression

# %%
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
Scaler.fit(x_train)
x_train=Scaler.transform(x_train)
x_test=Scaler.transform(x_test)

# %% [markdown]
# **Model Implimentations and Evaluations**

# %% [markdown]
# Model creation(Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
lr_model=LinearRegression()
lr_model.fit(x_train,y_train)
y_pred_lr=lr_model.predict(x_test)

# %% [markdown]
# Evaluation Metrics(Linear Regression)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error
print("R2 SCORE                            :",r2_score(y_test,y_pred_lr))
print("MEAN ABSOLUTE ERROR            (MAE):",mean_absolute_error(y_test,y_pred_lr))
print("MEAN ABSOLUTE PERCENTGAE ERROR(MAPE):",mean_absolute_percentage_error(y_test,y_pred_lr))
k=mean_squared_error(y_test,y_pred_lr)
print("MEAN SQUARED ERROR             (MSE):",k)
print("ROOT MEAN SQUARED ERROR       (RMSE):",np.sqrt(k))
# Out:
# R2 SCORE                            : 0.9120761152172564
# MEAN ABSOLUTE ERROR            (MAE): 0.4019289697615524
# MEAN ABSOLUTE PERCENTGAE ERROR(MAPE): 0.12573136966934376
# MEAN SQUARED ERROR             (MSE): 0.2527588152764301
# ROOT MEAN SQUARED ERROR       (RMSE): 0.5027512459223051

# %% [markdown]
# Model creation(Decision Tree Regressor)

# %%
from sklearn.tree import DecisionTreeRegressor
dt_model=DecisionTreeRegressor()
dt_model.fit(x_train,y_train)
y_pred_dt=dt_model.predict(x_test)

# %% [markdown]
# Evaluation Metrics(Decision Tree Regressor)

# %%
print('R2 SCORE                            :',r2_score(y_test,y_pred_dt))
print('MEAN ABSOLUTE ERROR (MAE)           :',mean_absolute_error(y_test,y_pred_dt))
print('MEAN ABSOLUTE PERCENTAGE ERROR(MAPE):',mean_absolute_percentage_error(y_test,y_pred_dt))
k=mean_squared_error(y_test,y_pred_dt)
print('MEAN SQUARED ERROR (MSE)            :',k)
print('ROOT MEAN SQUARED ERROR (RMSE)      :',np.sqrt(k))
# Out:
# R2 SCORE                            : 0.8164015156075684
# MEAN ABSOLUTE ERROR (MAE)           : 0.5794902615986615
# MEAN ABSOLUTE PERCENTAGE ERROR(MAPE): 0.1758883518223957
# MEAN SQUARED ERROR (MSE)            : 0.5277989651645494
# ROOT MEAN SQUARED ERROR (RMSE)      : 0.7264977392700884

# %% [markdown]
# Model creation (Random Forest Regressor)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model= RandomForestRegressor(n_estimators=100,random_state=42)
rf_model.fit(x_train,y_train)
y_pred_rf=rf_model.predict(x_test)

# %% [markdown]
# Evaluation Metrics(Random Forest Regression)

# %%
print("R2 SCORE                             :",r2_score(y_test,y_pred_rf))
print("MEAN ABSOLUTE ERROR (MAE)            :",mean_absolute_error(y_test,y_pred_rf))
print("MEAN ABSOLUTE PERCENTGAE ERROR (MAPE):",mean_absolute_percentage_error(y_test,y_pred_rf))
k=mean_squared_error(y_test,y_pred_rf)
print("MEAN SQUARED ERROR (MSE)             :",k)
print("ROOT MEAN SQUARED ERROR (RMSE)       :",np.sqrt(k))
# Out:
# R2 SCORE                             : 0.9049517487491326
# MEAN ABSOLUTE ERROR (MAE)            : 0.41708891141765636
# MEAN ABSOLUTE PERCENTGAE ERROR (MAPE): 0.13011882902256108
# MEAN SQUARED ERROR (MSE)             : 0.27323955759721863
# ROOT MEAN SQUARED ERROR (RMSE)       : 0.5227232131799951
